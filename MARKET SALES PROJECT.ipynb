# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # market sales project

# %%
df=pd.read_csv('market sales.csv')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.groupby(['Branch'])['gross income'].mean()
# Out:
# Branch
# A    14.874001
# B    15.232024
# C    16.052367
# Name: gross income, dtype: float64

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['month']=df['Date'].dt.month_name()

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
i=df.groupby(['Date'])['gross income'].sum().reset_index()

# %%
i
# Out:
#          Date  gross income
# 0  2019-01-01      225.9610
# 1  2019-01-02       92.6430
# 2  2019-01-03       98.9585
# 3  2019-01-04       77.3185
# 4  2019-01-05      168.4135
# ..        ...           ...
# 84 2019-03-26       93.4530
# 85 2019-03-27      138.2295
# 86 2019-03-28      106.1620
# 87 2019-03-29      191.5830
# 88 2019-03-30      213.6695
#
# [89 rows x 2 columns]

# %%
total=(df['Unit price'])*df['Quantity']+df['Tax 5%']

# %%
total
# Out:
# 0       548.9715
# 1        80.2200
# 2       340.5255
# 3       489.0480
# 4       634.3785
#          ...
# 995      42.3675
# 996    1022.4900
# 997      33.4320
# 998      69.1110
# 999     649.2990
# Length: 1000, dtype: float64

# %%
cogs=df['Quantity']*(df['Unit price'])
cogs
# Out:
# 0      522.83
# 1       76.40
# 2      324.31
# 3      465.76
# 4      604.17
#         ...
# 995     40.35
# 996    973.80
# 997     31.84
# 998     65.82
# 999    618.38
# Length: 1000, dtype: float64

# %%
gross_margin=(df['Total']-df['cogs'])/df['Total']*(100)
gross_margin
# Out:
# 0      4.761905
# 1      4.761905
# 2      4.761905
# 3      4.761905
# 4      4.761905
#          ...
# 995    4.761905
# 996    4.761905
# 997    4.761905
# 998    4.761905
# 999    4.761905
# Length: 1000, dtype: float64

# %%
## find object variable in dataset
obj=[col for col in df.columns if df[col].dtype=='object']
print('the object variable are:',obj)
# Out:
# the object variable are: ['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender', 'Product line', 'Time', 'Payment', 'month']

# %%
## find numaricle variable in dataset
numerical= [col for col in df.columns if df[col].dtype!='object']
print('the numerical variable are:', numerical)
# Out:
# the numerical variable are: ['Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'cogs', 'gross margin percentage', 'gross income', 'Rating']

# %%
df1=df

# %%
sns.boxplot(df1['Unit price'],data=df);

# %%
print('the count of unique values in city variable is' ,df['City'].unique())
# Out:
# the count of unique values in city variable is ['Yangon' 'Naypyitaw' 'Mandalay']

# %%
fig,ax = plt.subplots(1,5)
fig.set_size_inches(22,6)
sns.countplot(x = 'Branch', data = df1,ax=ax[0])
sns.countplot(x = 'City', data = df1, ax=ax[1])
sns.countplot(x = 'Customer type', data = df1, ax=ax[2])
sns.countplot(x = 'Gender', data = df1, ax=ax[3])
sns.countplot(x = 'Payment', data = df1, ax=ax[4]);

# %%
pd.pivot_table(df1, index = 'Product line', columns = 'Branch', values = 'gross income', aggfunc = ['count', 'mean'])
# Out:
#                        count               mean
# Branch                     A   B   C          A          B          C
# Product line
# Electronic accessories    60  55  55  14.537392  14.763155  16.423355
# Fashion accessories       51  62  65  15.249775  12.606234  15.794923
# Food and beverages        58  50  66  14.091216  14.490370  17.147803
# Health and beauty         47  53  52  12.763681  17.952075  15.215500
# Home and lifestyle        65  50  45  16.422854  16.713490  14.704289
# Sports and travel         59  62  45  15.635754  15.351919  16.679289

# %%
df1.groupby(['Product line','Branch'])['gross income'].agg(['count','mean'])
# Out:
#                                count       mean
# Product line           Branch
# Electronic accessories A          60  14.537392
#                        B          55  14.763155
#                        C          55  16.423355
# Fashion accessories    A          51  15.249775
#                        B          62  12.606234
#                        C          65  15.794923
# Food and beverages     A          58  14.091216
#                        B          50  14.490370
#                        C          66  17.147803
# Health and beauty      A          47  12.763681
#                        B          53  17.952075
#                        C          52  15.215500
# Home and lifestyle     A          65  16.422854
#                        B          50  16.713490
#                        C          45  14.704289
# Sports and travel      A          59  15.635754
#                        B          62  15.351919
#                        C          45  16.679289
